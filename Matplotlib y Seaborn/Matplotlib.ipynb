# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Pyplot básico

# %%
x = np.linspace(0,5, 11)
y = x**2

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, "ro-") #r de red, x tipo de punto y - para indicar linea
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# ## Subplot

# %%
#para realizar dos gráficos al mismo tiempo
plt.subplot(1, 2, 1) #los primeros dos numeros son las filas y las columnas, y el último número es el gráfico al cual me refiero
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.hist(y)
plt.show()

# %%
#para realizar dos gráficos al mismo tiempo
plt.subplot(1, 2, 1) 
plt.plot(x, y, "xo-")
plt.plot(y, x, "bo-")
plt.subplot(1, 2, 2)
plt.hist(y)
plt.show()

# %% [markdown]
# ## Método orientado a objeto

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.5,0.9])
axes.plot(x,y, "b")
fig.show()
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_12980\2443586763.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.9])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes.plot(x,y, "b")
axes2.plot(x,y, "r")
axes2.set_facecolor("grey")
fig.show()
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_12980\2833160748.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Subplots
# Igual que subplot pero trabaja orientado a objetos

# %%
fig, axes =plt.subplots(nrows=1, ncols=2, figsize= (8,5))
axes[0].plot(x, y, label="$x^2$")
axes[0].set_title("Relación x-y")
axes[0].set_xlabel("X")
axes[0].set_ylabel("Y")
axes[0].legend()

axes[1].plot(y, x, "r")
axes[1].set_title("Relación y-x")
axes[1].set_xlabel("X")
axes[1].set_ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ## Colores y estilos

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("bmh")

# %%
fig, axes = plt.subplots(figsize=(8,8))

axes.plot(x, x+1, "r--")
axes.plot(x, x+2, "b-")
axes.plot(x, x+3, "g.")

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x, y, color ="red", alpha=0.8, linewidth=2, linestyle="--", 
marker="v", markersize=10, markerfacecolor="blue")

# %% [markdown]
# ## Barplot

# %%
country=["India", "Japon", "Mexico", "Colombia", "Alemania"]
population=[1000, 800, 900, 1000, 300]

# %%
plt.style.use("Solarize_Light2")
plt.bar(country, population, width=0.8, color=["red", "blue"])
plt.xticks(np.arange(5), ("India", "Japon", "Mexico", "Colombia", "Alemania"), rotation=45)
plt.show()

# %%
plt.barh(country, population)
plt.show()

# %% [markdown]
# ## Otras gráficas

# %%
data = np.random.randint(1, 50, 100)

# %%
plt.hist(data, bins=15, histtype="step", color="red")
plt.show()

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True, showfliers=True)
plt.show()

# %%
N = 50
x=np.random.rand(N)
y=np.random.rand(N)
area = (30*np.random.rand(N))**2
colors = np.random.rand(N)

# %%
plt.scatter(x,y, s=area, c=colors, marker="o", alpha=0.5)
plt.show()
