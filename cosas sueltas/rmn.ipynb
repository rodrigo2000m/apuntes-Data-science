# %%
import pandas as pd
import seaborn as sns

# %%
rmn_data = pd.read_csv("rmn_data.csv", sep="\t", decimal=".", header=None)

# %%
rmn_data
# Out:
#                0    1         2
# 0      -1.999634  0.0 -0.000039
# 1      -1.999268  0.0 -0.000039
# 2      -1.998901  0.0 -0.000039
# 3      -1.998535  0.0 -0.000039
# 4      -1.998169  0.0 -0.000039
# ...          ...  ...       ...
# 32763   9.998535  0.0 -0.000040
# 32764   9.998901  0.0 -0.000039
# 32765   9.999268  0.0 -0.000039
# 32766   9.999634  0.0 -0.000039
# 32767  10.000000  0.0 -0.000039
#
# [32768 rows x 3 columns]

# %%
sns.relplot(rmn_data, x=0, y=1, kind="line", aspect=2)
